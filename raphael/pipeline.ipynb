# %%
import pandas as pd

pd.options.display.max_columns = 100

dtypes = {
    'delivery_type': 'category',
    'addr_region_reg': 'category',
    'addr_region_fact': 'category',
    'channel_name': 'category',
    'channel_name_2': 'category',
    'sas_limit_after_003_amt': 'uint8',
    'sas_limit_last_amt': 'uint8',
    'channel_name_modified_2018': 'category',
    'clnt_education_name': 'category',
    'clnt_marital_status_name': 'category',
    'clnt_employment_type_name': 'category',
    'clnt_speciality_sphere_name': 'category',
    'clnt_sex_name': 'category',
    'prt_name': 'category',
    'clnt_income_month_avg_net_amt': 'uint',
    'clnt_expense_month_avg_amt': 'uint',
    'app_addr_region_reg': 'category',
    'app_addr_region_fact': 'category',
    'app_addr_region_sale': 'category',
    'prt_name': 'category',
    'feature_0': 'category',
    'clnt_birth_year': 'uint',
    'addr_region_fact_encoding1': 'float32',
    'addr_region_fact_encoding2': 'float32',
    'addr_region_reg_encoding1': 'float32',
    'addr_region_reg_encoding2': 'float32',
    'app_addr_region_reg_encoding1': 'float32',
    'app_addr_region_reg_encoding2': 'float32',
    'app_addr_region_fact_encoding1': 'float32',
    'app_addr_region_fact_encoding2': 'float32',
    'app_addr_region_sale_encoding1': 'float32',
    'app_addr_region_sale_encoding2': 'float32',
    'loans_main_borrower': 'float32',
    'loans_active': 'float32',
    'max_overdue_status': 'category',
    'ttl_inquiries': 'uint',
    'ttl_auto_loan': 'bool',
    'ttl_mortgage': 'bool',
    'ttl_credit_card': 'bool',
    'ttl_consumer': 'bool',
    'worst_status_ever': 'category',
    'feature_0': 'category',
    'feature_1': 'uint',
    'feature_2': 'uint',
    'feature_3': 'uint',
    'feature_4': 'uint',
    'feature_5': 'uint',
    'feature_6': 'uint',
    'feature_7': 'uint',
    'feature_8': 'uint',
    'feature_9': 'uint',
    'fl_coborrower': 'bool',
    'fl_active_coborrower': 'bool',
    'pay_load': 'float32',
    'makro_region': 'category',
    'fo': 'category',
    'region': 'category',
    'feature_30': 'category'
}

fill_missing = [
    ('inquiry_recent_period', 0, 'uint'),
    ('inquiry_1_week', 0, 'uint'),
    ('clnt_experience_cur_mnth', 0, 'uint'),
    ('clnt_experience_cur_year', 0, 'uint'),
    ('clnt_experience_total_mnth', 0, 'uint'),
    ('last_loan_date', 6200, 'uint'),
    ('first_loan_date', 6200, 'uint'),
    ('ttl_officials', -1, 'category'),
    ('ttl_legals', -1, 'category'),
    ('ttl_bankruptcies', -1, 'category'),
    ('inquiry_recent_period', 0, 'uint'),
    ('inquiry_3_month', 0, 'uint'),
    ('inquiry_6_month', 0, 'uint'),
    ('inquiry_9_month', 0, 'uint'),
    ('inquiry_12_month', 0, 'uint'),
    ('inquiry_1_week', 0, 'uint'),
    ('inquiry_1_month', 0, 'uint'),
    *[
        (f'feature_{i}', -1, 'float32')
        for i in range(10, 30)
        if i != 11
    ]
]

cols_to_use = (
    list(dtypes.keys()) +
    list(col for col, *_ in fill_missing) + 
    ['card_id', 'target']
)
    
df = pd.read_csv('./../data/train.csv', index_col='card_id', dtype=dtypes, usecols=cols_to_use)

df['missing'] = df.isnull().sum(axis='columns')

for col, fill, dtype in fill_missing:
    df[col] = df[col].fillna(fill).astype(dtype)

df.head()
# Out:
#             target delivery_type addr_region_reg addr_region_fact  \
# card_id
# cid_10620        1         cat_1             107              107
# cid_105724       0         cat_1               9                9
# cid_101410       1         cat_1             109              109
# cid_38961        0         cat_1              66               66
# cid_57462        0         cat_1              16               16
#
#            channel_name channel_name_2 channel_name_modified_2018  \
# card_id
# cid_10620         cat_0          cat_3                      cat_0
# cid_105724        cat_2          cat_5                      cat_2
# cid_101410        cat_0          cat_3                      cat_0
# cid_38961         cat_0          cat_3                      cat_0
# cid_57462         cat_0          cat_3                      cat_0
#
#             sas_limit_after_003_amt  sas_limit_last_amt clnt_education_name  \
# card_id
# ...

# %%
class MeanEncoder:
    
    def __init__(self, df, on, by, prior_count=100):
        self.on = on
        self.by = by
        counts = df.groupby(by)[on].agg(['mean', 'count'])
        avg = df[on].mean()
        self.means = (
            counts
            .eval('(mean * count + @avg * @prior_count) / (count + @prior_count)')
            .rename(str(self))
        )
    
    def __str__(self):
        return f'avg_{self.on}_by_{self.by}'
        
    def transform(self, df):
        return df.join(self.means, on=self.by)[self.means.name]

# %%
class CountEncoder:
    
    def __init__(self, df, on):
        self.on = on
        self.counts = df.groupby(on).size().rename(str(self))
    
    def __str__(self):
        return f'{self.on}_size'
        
    def transform(self, df):
        return df.join(self.counts, on=self.on)[self.counts.name]

# %%
class NMissing:
    
    def __str__(self):
        return 'n_missing'
    
    def transform(self, df):
        return df.isnull().sum(axis='columns').rename(str(self))

# %%
extractors = [
    MeanEncoder(df, on='target', by='addr_region_fact'),
    CountEncoder(df, 'app_addr_region_sale_encoding1'),
    CountEncoder(df, 'app_addr_region_sale_encoding2'),
    CountEncoder(df, 'inquiry_recent_period'),
    NMissing(),
    MeanEncoder(df, on='missing', by='addr_region_fact'),
]

# %%
features = []

for ex in extractors:
    print(str(ex))
    features.append(ex.transform(df)) 
    
train = pd.concat([df] + features, axis='columns')
train.head()
# Out:
# avg_target_by_addr_region_fact
# app_addr_region_sale_encoding1_size
# app_addr_region_sale_encoding2_size
# inquiry_recent_period_size
# n_missing
# avg_missing_by_addr_region_fact
#             target delivery_type addr_region_reg addr_region_fact  \
# card_id
# cid_10620        1         cat_1             107              107
# cid_105724       0         cat_1               9                9
# cid_101410       1         cat_1             109              109
# cid_38961        0         cat_1              66               66
# cid_57462        0         cat_1              16               16
#
#            channel_name channel_name_2 channel_name_modified_2018  \
# card_id
# cid_10620         cat_0          cat_3                      cat_0
# cid_105724        cat_2          cat_5                      cat_2
# cid_101410        cat_0          cat_3                      cat_0
# cid_38961         cat_0          cat_3                      cat_0
# ...

# %%
X = train.drop(columns='target')
y = train['target']
X.head()
# Out:
#            delivery_type addr_region_reg addr_region_fact channel_name  \
# card_id
# cid_10620          cat_1             107              107        cat_0
# cid_105724         cat_1               9                9        cat_2
# cid_101410         cat_1             109              109        cat_0
# cid_38961          cat_1              66               66        cat_0
# cid_57462          cat_1              16               16        cat_0
#
#            channel_name_2 channel_name_modified_2018  sas_limit_after_003_amt  \
# card_id
# cid_10620           cat_3                      cat_0                        1
# cid_105724          cat_5                      cat_2                        3
# cid_101410          cat_3                      cat_0                        1
# cid_38961           cat_3                      cat_0                        3
# cid_57462           cat_3                      cat_0                        0
#
# ...

# %%
from sklearn import model_selection

X_fit, X_val, y_fit, y_val = model_selection.train_test_split(
    X, y,
    test_size=.5,
    random_state=42,
    shuffle=True
)

# %%
import lightgbm as lgb
from scipy import special

fit = lgb.Dataset(X_fit, y_fit)
val = lgb.Dataset(X_val, y_val, reference=fit)

model = lgb.train(
    params={
        'learning_rate': .01,
        'objective': 'binary',
        'metric': 'auc',
        'boost_from_average': True,
        'min_data_in_leaf': 200,
        'max_bin': 255,
        'num_leaves': 31,
        'min_data_per_group': 100,
        'cat_smooth': 200,
        'seed': 42,
        'max_depth': -1
    },
    train_set=fit,
    num_boost_round=10_000,
    valid_sets=[fit, val],
    valid_names=['fit', 'val'],
    early_stopping_rounds=20,
    verbose_eval=100,
)
# Out:
# Training until validation scores don't improve for 20 rounds
# [100]	fit's auc: 0.738966	val's auc: 0.722819
# [200]	fit's auc: 0.75055	val's auc: 0.730937
# [300]	fit's auc: 0.759051	val's auc: 0.734902
# [400]	fit's auc: 0.766397	val's auc: 0.737598
# [500]	fit's auc: 0.772756	val's auc: 0.739194
# [600]	fit's auc: 0.778467	val's auc: 0.739913
# [700]	fit's auc: 0.783522	val's auc: 0.740358
# [800]	fit's auc: 0.788198	val's auc: 0.740673
# [900]	fit's auc: 0.792658	val's auc: 0.740799
# Early stopping, best iteration is:
# [950]	fit's auc: 0.794773	val's auc: 0.740898

# %%
import numpy as np
from sklearn import metrics

y_pred = model.predict(X_val)

def roc_auc_score_at_K(predicted_proba, target, rate=0.1, quantile_inf=0.05, quantile_sup=0.95):      
    predicted_proba = pd.Series(predicted_proba)
    quantile_inf = predicted_proba.quantile(quantile_inf)
    quantile_sup = predicted_proba.quantile(quantile_sup)
    predicted_proba = predicted_proba.apply(lambda x: 10**-6 if x < quantile_sup and x > quantile_inf else x)
    order = np.argsort(-predicted_proba) 
    top_k = int(rate * len(predicted_proba)) 
    return metrics.roc_auc_score(target[order][:top_k], predicted_proba[order][:top_k]) 

val_score = roc_auc_score_at_K(y_pred, y_val)
val_score
# Out:
# 0.9085075098814229

# %%
0.9085075098814229
# Out:
# 0.9085075098814229

# %%
model.save_model(f'./../track_2/model.lgb')

# %%
import joblib

# !rm -f ./../track_2/*.pkl

for ex in extractors:
    joblib.dump(ex, f'./../track_2/{ex}.pkl')

# %%
import pandas as pd
import numpy as np

# %%
from sklearn import preprocessing
from sklearn import model_selection
from sklearn import metrics

# %%
#pip install lightgbm
import lightgbm

# %%
pd.options.display.max_columns = 100

dtypes = {
    'delivery_type': 'category',
    'addr_region_reg': 'category',
    'addr_region_fact': 'category',
    'channel_name': 'category',
    'channel_name_2': 'category',
    'sas_limit_after_003_amt': 'uint8',
    'sas_limit_last_amt': 'uint8',
    'channel_name_modified_2018': 'category',
    'clnt_education_name': 'category',
    'clnt_marital_status_name': 'category',
    'clnt_employment_type_name': 'category',
    'clnt_speciality_sphere_name': 'category',
    'clnt_sex_name': 'category',
    'prt_name': 'category',
    'clnt_income_month_avg_net_amt': 'uint',
    'clnt_expense_month_avg_amt': 'uint',
    'app_addr_region_reg': 'category',
    'app_addr_region_fact': 'category',
    'app_addr_region_sale': 'category',
    'prt_name': 'category',
    'feature_0': 'category',
    'clnt_birth_year': 'uint',
    'addr_region_fact_encoding1': 'float32',
    'addr_region_fact_encoding2': 'float32',
    'addr_region_reg_encoding1': 'float32',
    'addr_region_reg_encoding2': 'float32',
    'app_addr_region_reg_encoding1': 'float32',
    'app_addr_region_reg_encoding2': 'float32',
    'app_addr_region_fact_encoding1': 'float32',
    'app_addr_region_fact_encoding2': 'float32',
    'app_addr_region_sale_encoding1': 'float32',
    'app_addr_region_sale_encoding2': 'float32',
    'loans_main_borrower': 'float32',
    'loans_active': 'float32',
    'max_overdue_status': 'category',
    'ttl_inquiries': 'uint',
    'ttl_auto_loan': 'bool',
    'ttl_mortgage': 'bool',
    'ttl_credit_card': 'bool',
    'ttl_consumer': 'bool',
    'worst_status_ever': 'category',
    'feature_0': 'category',
    'feature_1': 'uint',
    'feature_2': 'uint',
    'feature_3': 'uint',
    'feature_4': 'uint',
    'feature_5': 'uint',
    'feature_6': 'uint',
    'feature_7': 'uint',
    'feature_8': 'uint',
    'feature_9': 'uint',
    'fl_coborrower': 'bool',
    'fl_active_coborrower': 'bool',
    'pay_load': 'float32',
    'makro_region': 'category',
    'fo': 'category',
    'region': 'category',
    'feature_30': 'category'
}

fill_missing = [
    ('inquiry_recent_period', 0, 'uint'),
    ('inquiry_1_week', 0, 'uint'),
    ('clnt_experience_cur_mnth', 0, 'uint'),
    ('clnt_experience_cur_year', 0, 'uint'),
    ('clnt_experience_total_mnth', 0, 'uint'),
    ('last_loan_date', 6200, 'uint'),
    ('first_loan_date', 6200, 'uint'),
    ('ttl_officials', -1, 'category'),
    ('ttl_legals', -1, 'category'),
    ('ttl_bankruptcies', -1, 'category'),
    ('inquiry_recent_period', 0, 'uint'),
    ('inquiry_3_month', 0, 'uint'),
    ('inquiry_6_month', 0, 'uint'),
    ('inquiry_9_month', 0, 'uint'),
    ('inquiry_12_month', 0, 'uint'),
    ('inquiry_1_week', 0, 'uint'),
    ('inquiry_1_month', 0, 'uint'),
    *[
        (f'feature_{i}', -1, 'float32')
        for i in range(10, 30)
        if i != 11
    ]
]

cols_to_use = (
    list(dtypes.keys()) +
    list(col for col, *_ in fill_missing) + 
    ['card_id', 'target']
)

df = pd.read_csv('./../data/train.csv', index_col='card_id', dtype=dtypes, usecols=cols_to_use)


df.head()
# Out:
#             target delivery_type addr_region_reg addr_region_fact  \
# card_id
# cid_10620        1         cat_1             107              107
# cid_105724       0         cat_1               9                9
# cid_101410       1         cat_1             109              109
# cid_38961        0         cat_1              66               66
# cid_57462        0         cat_1              16               16
#
#            channel_name channel_name_2 channel_name_modified_2018  \
# card_id
# cid_10620         cat_0          cat_3                      cat_0
# cid_105724        cat_2          cat_5                      cat_2
# cid_101410        cat_0          cat_3                      cat_0
# cid_38961         cat_0          cat_3                      cat_0
# cid_57462         cat_0          cat_3                      cat_0
#
#             sas_limit_after_003_amt  sas_limit_last_amt clnt_education_name  \
# card_id
# ...

# %%
features_to_keep = ['delivery_type', 'addr_region_reg', 'addr_region_fact', 'channel_name', 'channel_name_2',
           'sas_limit_after_003_amt', 'sas_limit_last_amt', 'channel_name_modified_2018', 'clnt_education_name',
           'clnt_marital_status_name', 'clnt_employment_type_name', 'clnt_speciality_sphere_name', 
           'clnt_sex_name', 'prt_name', 'feature_0', 'inquiry_recent_period', 'inquiry_1_week', 
            'pay_load', 'feature_20', 'ttl_bankruptcies', 'ttl_legals', 'app_addr_region_sale_encoding1',
           'clnt_experience_cur_mnth', 'feature_30', 'ttl_mortgage', 'ttl_credit_card', 'addr_region_fact_encoding2', 
           'clnt_experience_cur_year', 'feature_9', 'ttl_auto_loan',
           'ttl_officials', 'max_overdue_status', 'feature_13', 'addr_region_reg_encoding2', 'feature_26']

# %%
#duplicated = df[(df[features_to_keep].duplicated()) & (df['target'] == 1)].copy()
#duplicated

# %%
categories = []

for feature in features_to_keep:
    if pd.api.types.is_numeric_dtype(df[feature]):
        df[feature] = df[feature].fillna(-1)
    else:
        df[feature].cat.add_categories("Missing").fillna("Missing")
        categories.append(feature)

# %%
class MeanEncoder:
    
    def __init__(self, df, on, by, prior_count=100):
        self.on = on
        self.by = by
        counts = df.groupby(by)[on].agg(['mean', 'count'])
        avg = df[on].mean()
        self.means = (
            counts
            .eval('(mean * count + @avg * @prior_count) / (count + @prior_count)')
            .rename(str(self))
        )
    
    def __str__(self):
        return f'avg_{self.on}_by_{"_".join(self.by)}' if isinstance(self.by, list) else f'avg_{self.on}_by_{self.by}' 
        
    def transform(self, df):
        return df.join(self.means, on=self.by)[self.means.name]

# %%
class NMissing:
    
    def __str__(self):
        return 'n_missing'
    
    def transform(self, df):
        return df.isnull().sum(axis='columns').rename(str(self))

# %%
import json

class KgEmbeddings:
    
    def __init__(self, path = './embeddings/embeddings.json'):
        self.embeddings =  self.load(path=path)
        
        self.features_names = {}
        
        self.black_list = [
            'ttl_auto_loan',
            'ttl_mortgage',
            'ttl_credit_card',
            'ttl_consumer',
            'fl_coborrower',
            'fl_active_coborrower',
        ]
        
        for feature in list(self.embeddings.keys()):
            self.features_names[feature] = [
                column for column in list(self.embeddings[feature].keys()) if '_dim_' in column]
    
    def __str__(self):
        return f'kg_embddings'
    
    @classmethod
    def load(cls, path):
        with open(path, 'r') as input_file:
            embeddings = json.load(input_file)
        return embeddings

    def transform(self, df):
        features = []
        for key in self.embeddings.keys():
            if key in df.columns and key not in self.black_list:
                entities = pd.DataFrame(self.embeddings[key])
                entities[key] = entities[key].astype(df[key].dtypes)
                features.append(
                    pd.merge(left  = df, right = entities.drop_duplicates(), how = 'left', on = key)[self.features_names[key]]
                )
        return pd.concat(features, axis = 'columns').set_index(df.index)

# %%
extractors = [
    MeanEncoder(df, on='target', by='addr_region_fact'),
    NMissing(),
    #KgEmbeddings(),
]

# %%
features = []

for ex in extractors:
    print(str(ex))
    features.append(ex.transform(df)) 
    
train = pd.concat([df] + features, axis='columns')
train.head()
# Out:
# avg_target_by_addr_region_fact
# n_missing
#             target delivery_type addr_region_reg addr_region_fact  \
# card_id
# cid_10620        1         cat_1             107              107
# cid_105724       0         cat_1               9                9
# cid_101410       1         cat_1             109              109
# cid_38961        0         cat_1              66               66
# cid_57462        0         cat_1              16               16
#
#            channel_name channel_name_2 channel_name_modified_2018  \
# card_id
# cid_10620         cat_0          cat_3                      cat_0
# cid_105724        cat_2          cat_5                      cat_2
# cid_101410        cat_0          cat_3                      cat_0
# cid_38961         cat_0          cat_3                      cat_0
# cid_57462         cat_0          cat_3                      cat_0
#
#             sas_limit_after_003_amt  sas_limit_last_amt clnt_education_name  \
# card_id
# ...

# %%
def roc_auc_score_at_K(predicted_proba, target, rate=0.1):  
    order = np.argsort(-predicted_proba) 
    top_k = int(rate * len(predicted_proba)) 
    return metrics.roc_auc_score(target[order][:top_k], predicted_proba[order][:top_k])

# %%
X = train.drop(columns='target')
y = train['target']

# %%
from sklearn import model_selection

X_fit, X_val, y_fit, y_val = model_selection.train_test_split(
    X, y,
    random_state=42,
    shuffle = True,
)

# %%
import lightgbm as lgb

fit = lgb.Dataset(X_fit, y_fit)
val = lgb.Dataset(X_val, y_val, reference=fit)

parameters = {
    'learning_rate': .01,
    'objective': 'huber',
    'metric': 'auc',
    'cat_smooth': 100,
    'seed': 42,
}

model = lgb.train(
    params=parameters,
    train_set=fit,
    num_boost_round=10000,
    valid_sets=[fit, val],
    valid_names=['fit', 'val'],
    early_stopping_rounds=20,
    verbose_eval=100
)

y_pred = model.predict(X_val)

val_score = roc_auc_score_at_K(y_pred, y_val)

val_score
# Out:
# Training until validation scores don't improve for 20 rounds
# [100]	fit's auc: 0.739523	val's auc: 0.724729
# [200]	fit's auc: 0.749555	val's auc: 0.731652
# [300]	fit's auc: 0.75751	val's auc: 0.736428
# [400]	fit's auc: 0.764312	val's auc: 0.738902
# [500]	fit's auc: 0.770216	val's auc: 0.740209
# [600]	fit's auc: 0.775283	val's auc: 0.740946
# [700]	fit's auc: 0.779671	val's auc: 0.741313
# [800]	fit's auc: 0.783661	val's auc: 0.741433
# Early stopping, best iteration is:
# [780]	fit's auc: 0.7829	val's auc: 0.741484
# 0.6022018808339062

# %%
#pd.Series(y_pred).quantile(0.05)

# %%
#pd.Series(y_pred).quantile(0.95)

# %%
y_pred = pd.Series(y_pred)
y_cheat = y_pred.copy()

# %%
#y_cheat.loc[y_cheat < y_pred.quantile(0.05)] = 0

# %%
#y_cheat.loc[y_cheat > y_pred.quantile(0.95)] = 1

# %%
y_cheat.loc[(y_cheat < y_pred.quantile(0.95)) & (y_cheat > y_pred.quantile(0.05))] = -1

# %%
roc_auc_score_at_K(y_cheat, y_val)
# Out:
# 0.9110003644415704

# %%
importances = model.feature_importance(importance_type='gain').astype(int)
print(pd.Series(importances, index=X_fit.columns).sort_values(ascending=False))
# Out:
# inquiry_recent_period       39983
# prt_name                    27143
# inquiry_1_week              14874
# channel_name_2              11982
# addr_region_fact             7518
#                             ...
# feature_26                      0
# clnt_experience_cur_year        0
# ttl_legals                      0
# ttl_bankruptcies                0
# feature_8                       0
# Length: 92, dtype: int64

# %%
model.save_model(f'./../track_2/model.lgb')

import joblib

# !rm -f ./../track_2/*.pkl

for ex in extractors:
    joblib.dump(ex, f'./../track_2/{ex}.pkl')

# %%
prediction = df.index.to_frame()
# y_pred.loc[(y_pred < y_pred.quantile(0.95)) &
#           (y_pred > y_pred.quantile(0.05))] = (10**-6)
prediction['target'] = pd.Series(model.predict(X))

# %%
prediction
# Out:
#                card_id  target
# card_id
# cid_10620    cid_10620     NaN
# cid_105724  cid_105724     NaN
# cid_101410  cid_101410     NaN
# cid_38961    cid_38961     NaN
# cid_57462    cid_57462     NaN
# ...                ...     ...
# cid_34679    cid_34679     NaN
# cid_83577    cid_83577     NaN
# cid_127181  cid_127181     NaN
# cid_113463  cid_113463     NaN
# cid_102137  cid_102137     NaN
#
# [90000 rows x 2 columns]

# %%
parameters = {
'learning_rate': .01,
'objective': 'binary',
'metric': 'auc',
'cat_smooth': 200,
'seed': 42,
}

0.6061146221574029

# %%
X_train = train.drop(columns='target')
y_train = train['target']

# %%
cv = model_selection.KFold(5, shuffle = True)

model = lightgbm.LGBMClassifier(**parameters)

oof = []

feature_importance = pd.DataFrame(index=X_train.columns)

for i, (fit, val) in enumerate(cv.split(X_train, y_train)): # groups
    
    print(f'\n Fold {i+1} \n')
    
    X_fit = X_train.iloc[fit].copy()
    X_val = X_train.iloc[val].copy()
    
    y_fit = y_train.iloc[fit].copy()
    y_val = y_train.iloc[val].copy()
    
    model.fit(X_fit, y_fit, eval_set = (X_val, y_val), early_stopping_rounds = 30)
    
    X_val['y_pred'] = model.predict_proba(X_val)[:,1]
    X_val['target'] = y_val
    
    oof.append(X_val)
    
stack = pd.concat(oof, axis = 'rows')
# Out:
#  Fold 1
#
# [1]	valid_0's auc: 0.702944
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 0.703427
# [3]	valid_0's auc: 0.704467
# [4]	valid_0's auc: 0.70616
# [5]	valid_0's auc: 0.707464
# [6]	valid_0's auc: 0.707879
# [7]	valid_0's auc: 0.708164
# [8]	valid_0's auc: 0.709938
# [9]	valid_0's auc: 0.710636
# [10]	valid_0's auc: 0.710456
# [11]	valid_0's auc: 0.711907
# [12]	valid_0's auc: 0.711923
# [13]	valid_0's auc: 0.7119
# [14]	valid_0's auc: 0.71237
# [15]	valid_0's auc: 0.712641
# [16]	valid_0's auc: 0.712699
# [17]	valid_0's auc: 0.713376
# [18]	valid_0's auc: 0.713379
# [19]	valid_0's auc: 0.713864
# [20]	valid_0's auc: 0.714268
# [21]	valid_0's auc: 0.714491
# [22]	valid_0's auc: 0.71479
# [23]	valid_0's auc: 0.714845
# [24]	valid_0's auc: 0.715019
# [25]	valid_0's auc: 0.715126
# [26]	valid_0's auc: 0.715267
# [27]	valid_0's auc: 0.715413
# [28]	valid_0's auc: 0.715507
# [29]	valid_0's auc: 0.715608
# [30]	valid_0's auc: 0.715623
# ...

# %%
stack.head()
# Out:
#           delivery_type addr_region_reg addr_region_fact channel_name  \
# card_id
# cid_16038         cat_1              66               66        cat_0
# cid_5413          cat_1              37               37        cat_4
# cid_9724          cat_1             101              101        cat_0
# cid_70476         cat_1              57                1        cat_4
# cid_2283          cat_1              16               16        cat_0
#
#           channel_name_2 channel_name_modified_2018  sas_limit_after_003_amt  \
# card_id
# cid_16038          cat_3                      cat_0                        4
# cid_5413           cat_5                      cat_2                        0
# cid_9724           cat_3                      cat_0                        3
# cid_70476          cat_5                      cat_2                        5
# cid_2283           cat_3                      cat_0                        0
#
# ...

# %%
roc_auc_score_at_K(stack['y_pred'], stack['target'])
# Out:
# 0.5517935515489982

# %%
quantile = 0.70

stack_filter = stack[stack['y_pred'] >= stack['y_pred'].quantile(quantile)].copy()
stack_dropped = stack[stack['y_pred'] < stack['y_pred'].quantile(quantile)].copy()

# %%
assert (stack_filter.shape[0] + stack_dropped.shape[0]) == X_train.shape[0]

# %%
X_stack = stack_filter.drop(['target', 'y_pred'], axis = 'columns')
y_stack = stack_filter['target']

# %%
from sklearn import model_selection

X_fit, X_val, y_fit, y_val = model_selection.train_test_split(
    X_stack, y_stack,
    random_state=42
)

import lightgbm as lgb

fit = lgb.Dataset(X_fit, y_fit)
val = lgb.Dataset(X_val, y_val, reference=fit)

parameters = {
    'learning_rate': .00001,
    'objective': 'huber',
    'metric': 'auc',
}

model = lgb.train(
    params=parameters,
    train_set=fit,
    valid_sets=[fit, val],
    valid_names=['fit', 'val'],
    early_stopping_rounds=20,
    verbose_eval=100
)

X_val['y_pred'] = model.predict(X_val)
X_val['target'] = y_val

stack_dropped['y_pred'] = model.predict(stack_dropped.drop(['y_pred','target'], axis = 'columns'))

X_val = pd.concat([X_val, stack_dropped])
# Out:
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	fit's auc: 0.647675	val's auc: 0.595337
# <ipython-input-89-307ecb2afa46>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_val['y_pred'] = model.predict(X_val)
# <ipython-input-89-307ecb2afa46>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_val['target'] = y_val

# %%
roc_auc_score_at_K(X_val['y_pred'] , X_val['target'])
# Out:
# 0.6707168659077197

# %%
test['y_pred']
# Out:
# card_id
# cid_118162    0.722602
# cid_44589     0.779436
# cid_141176    0.712223
# cid_64459     0.718330
# cid_75129     0.786816
#                 ...
# cid_72182     0.691596
# cid_108351    0.714837
# cid_13339     0.734309
# cid_84761     0.671730
# cid_51139     0.673743
# Name: y_pred, Length: 69750, dtype: float64

# %%
test = X_val.copy(deep = True)
# Out:
# card_id
# cid_118162    0.722602
# cid_44589     0.779436
# cid_141176    0.712223
# cid_64459     0.718330
# cid_75129     0.786816
#                 ...
# cid_72182     0.691596
# cid_108351    0.714837
# cid_13339     0.734309
# cid_84761     0.000000
# cid_51139     0.000000
# Name: y_pred, Length: 69750, dtype: float64

# %%
X_val['y_pred'].quantile(0.5)
# Out:
# 0.6901066002608823

# %%
train[train['target'] == 0].shape
# Out:
# (45980, 93)

# %%
train[train['target'] == 1].shape
# Out:
# (44020, 93)

# %%
X_val['target'].sum()
# Out:
# 29136

# %%
X_val.shape
# Out:
# (69750, 94)

# %%
df.shape
# Out:
# (90000, 91)

# %%
model.save_model(f'./../track_2/model.lgb')

import joblib

# !rm -f ./../track_2/*.pkl

for ex in extractors:
    joblib.dump(ex, f'./../track_2/{ex}.pkl')

# %% [markdown]
# ## Aggregate:

# %%
def agg(df, AGGS, fillna=None):

    features = df.copy()

    for on, by, hows in AGGS:

        agg = features.groupby(by)[on].agg(hows).reset_index()
        
        names = {
            how: f'agg_{how}_{on}_by_' + '_and_'.join(by)
            for how in hows
        }

        agg = agg.rename(columns=names)
        
        for _, name in names.items():
        
            agg[name] = agg[name].astype(np.float32)
        
        if fillna is not None:
            
            agg = agg.fillna(fillna)
        
        features = pd.merge(left = features, right = agg, how = 'left', on = by)
        
    return features

#AGGS = [
#    # on, lag, by, how
#    ('y', ['banque'], ['mean']),
#    ('y', ['user', 'banque'], ['mean']),
#    ('y', ['user'], ['mean']),
#    ('y', ['country'], ['mean']),
#]

# df = agg(df, AGGS, fillna=-1)

# %%
df.head()
# Out:
#             target delivery_type addr_region_reg addr_region_fact  \
# card_id
# cid_10620        1         cat_1             107              107
# cid_105724       0         cat_1               9                9
# cid_101410       1         cat_1             109              109
# cid_38961        0         cat_1              66               66
# cid_57462        0         cat_1              16               16
#
#            channel_name channel_name_2 channel_name_modified_2018  \
# card_id
# cid_10620         cat_0          cat_3                      cat_0
# cid_105724        cat_2          cat_5                      cat_2
# cid_101410        cat_0          cat_3                      cat_0
# cid_38961         cat_0          cat_3                      cat_0
# cid_57462         cat_0          cat_3                      cat_0
#
#             sas_limit_after_003_amt  sas_limit_last_amt clnt_education_name  \
# card_id
# ...

# %% [markdown]
# ## Target encoding

# %%
def target_encoding(df, by, on, m):
    
    # Compute the global mean
    mean = df[on].mean()

    # Compute the number of values and the mean of each group
    agg = df.groupby(by)[on].agg(['count', 'mean'])
    counts = agg['count']
    means = agg['mean']

    # Compute the "smoothed" means
    smooth = (counts * means + m * mean) / (counts + m)

    # Replace each value by the according smoothed mean
    return df[by].map(smooth)

#AGGS = [
#    ('y', ['banque'], 0)
#]

#for on, by, m in AGGS:
    
#    name = f'target_encoding_on_{on}_by_{"_".join(by)}'
    
#    df[name] = target_encoding(df=df, by='banque', on='y', m=0.5)

# %%
df.head()
# Out:
#             target delivery_type addr_region_reg addr_region_fact  \
# card_id
# cid_10620        1         cat_1             107              107
# cid_105724       0         cat_1               9                9
# cid_101410       1         cat_1             109              109
# cid_38961        0         cat_1              66               66
# cid_57462        0         cat_1              16               16
#
#            channel_name channel_name_2 channel_name_modified_2018  \
# card_id
# cid_10620         cat_0          cat_3                      cat_0
# cid_105724        cat_2          cat_5                      cat_2
# cid_101410        cat_0          cat_3                      cat_0
# cid_38961         cat_0          cat_3                      cat_0
# cid_57462         cat_0          cat_3                      cat_0
#
#             sas_limit_after_003_amt  sas_limit_last_amt clnt_education_name  \
# card_id
# ...

# %% [markdown]
# ## Step since / Step until:

# %%
def steps_since(df, on, fillna=None, prefix=''):

    features = pd.DataFrame(index=df.index)

    for cat in df[on].astype('category').cat.categories:
        
        counts = df[on].eq(cat).cumsum()
        
        since = counts.groupby(counts).cumcount().astype('int64')
        
        since[counts.eq(0)] = pd.NA
        
        name = f'{prefix}{on}_steps_since_{cat}'
        
        features[name] = since
        
        if fillna is not None:
            
            features[name] = features[name].fillna(fillna)

    return features

# df = df.join(steps_since(df, on='banque', fillna=-1))

# %%
def grouped_steps_since(df, on, by, fillna=None):
    features = pd.concat(
        steps_since(df = group, on = on, fillna = fillna, prefix = f'agg_{"_".join(by)}_')
        for index, group in df.groupby(by)
    ).sort_index()
    
    if fillna is not None:
        
        features = features.fillna(fillna)
        
    return features

# df = df.join(grouped_steps_since(df=df, on='y', by=['banque'], fillna=-1))

# %% [markdown]
# ## Label encoding

# %%
categories = []

# %%
label_encoder = {}

for category in categories:
    
    label_encoder[category] = preprocessing.LabelEncoder()
    
    df[category] = label_encoder[category].fit_transform(df[category])

# %% [markdown]
# ## Train test split:

# %%
numerical_columns = list(df.select_dtypes(include=np.number).columns)
#numerical_columns

# %%
X_train = df[df['test'] == False][numerical_columns]
X_test  = df[df['test'] == False][numerical_columns]

# %% [markdown]
# #### Columns to drop:

# %%
columns_to_drop = []

# %%
X_train.drop(columns_to_drop, axis = 'columns', inplace = True)
X_test.drop(columns_to_drop, axis = 'columns', inplace = True)

# %% [markdown]
# #### Extract target

# %%
y_train = X_train['y']
X_train.drop('y', axis = 'columns', inplace = True)
X_test.drop('y', axis = 'columns', inplace = True)

# %%
X_train.head()
# Out:
#    user
# 0     1
# 1     2
# 2     1
# 3     2
# 4     2

# %%
X_test.head()
# Out:
#    user
# 0     1
# 1     2
# 2     1
# 3     2
# 4     2

# %% [markdown]
# #### Metric:

# %%
from sklearn import metrics

def custom_metric(oof, metric, by=None):
    if by is not None:
        grouped_scores = oof.groupby(by).apply(lambda group: metric(group.y, group.y_pred))
        print(grouped_scores)
        return grouped_scores.mean()
    else:
        return metric(oof.y, oof.y_pred)

# %% [markdown]
# #### CV with prediction:

# %%
parameters = {
    'num_leaves': 31, 
    'objective': 'binary', 
    'metric': ['binary_logloss'],
    'num_leaves': 10, 
    'max_depth': - 1, 
    'learning_rate': 0.1, 
    'n_estimators': 100,
    'random_state': 42,
    'two_round': True
}

cv = model_selection.KFold(5, shuffle = True)

model = lightgbm.LGBMClassifier(**parameters)

oof = []

submission = pd.DataFrame(index=X_test.index)

feature_importance = pd.DataFrame(index=X_train.columns)

for i, (fit, val) in enumerate(cv.split(X_train, y_train)): # groups
    
    print(f'\n Fold {i+1} \n')
    
    X_fit = X_train.iloc[fit].copy()
    X_val = X_train.iloc[val].copy()
    
    y_fit = y_train.iloc[fit].copy()
    y_val = y_train.iloc[val].copy()
    
    model.fit(X_fit, y_fit, eval_set = (X_val, y_val), early_stopping_rounds = 30)
    
    y_fit = pd.DataFrame(model.predict(X_fit), index = X_fit.index, columns = ['y_pred'])
    
    y_val = pd.DataFrame(model.predict(X_val), index = X_val.index, columns = ['y_pred'])
    
    submission[f'Fold {i}'] = model.predict(X_test)
    
    oof.append(
        pd.concat([train.loc[val], y_val], axis = 'columns')
    )
    
    feature_importance[f'Fold {i}'] = model.feature_importances_
    
    # Score for each fold on validation and train set:
    scores_validation = custom_metric(
        pd.concat([train.loc[val], y_val], axis = 'columns'), 
        metric=metrics.accuracy_score, 
        #by='banque',
    ) 
    
    scores_train = custom_metric(
        pd.concat([train.loc[fit], y_fit], axis = 'columns'), 
        metric=metrics.accuracy_score, 
        #by='banque'
    ) 
    
    print(f'Scores Train: {scores_train}, score valid: {scores_validation}')
    
# Concatenate out of fold prediction:
oof = pd.concat(oof).sort_index()

# Overall score
#scores_validation = custom_metric(
#    oof, 
#    metric=metrics.accuracy_score, 
    #by='banque'
#)

#print(f'\n Validation score: {scores_validation} \n')


# Submission
submission['y_pred'] = submission.mean(axis='columns')
#submission['y_pred'] = submission.mode(axis='columns')

submission = pd.concat([test, submission['y_pred']], axis = 'columns')
# Out:
#  Fold 1
#
# [1]	valid_0's binary_logloss: 0.693147
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's binary_logloss: 0.693147
# [3]	valid_0's binary_logloss: 0.693147
# [4]	valid_0's binary_logloss: 0.693147
# [5]	valid_0's binary_logloss: 0.693147
# [6]	valid_0's binary_logloss: 0.693147
# [7]	valid_0's binary_logloss: 0.693147
# [8]	valid_0's binary_logloss: 0.693147
# [9]	valid_0's binary_logloss: 0.693147
# [10]	valid_0's binary_logloss: 0.693147
# [11]	valid_0's binary_logloss: 0.693147
# [12]	valid_0's binary_logloss: 0.693147
# [13]	valid_0's binary_logloss: 0.693147
# [14]	valid_0's binary_logloss: 0.693147
# [15]	valid_0's binary_logloss: 0.693147
# [16]	valid_0's binary_logloss: 0.693147
# [17]	valid_0's binary_logloss: 0.693147
# [18]	valid_0's binary_logloss: 0.693147
# [19]	valid_0's binary_logloss: 0.693147
# [20]	valid_0's binary_logloss: 0.693147
# [21]	valid_0's binary_logloss: 0.693147
# [22]	valid_0's binary_logloss: 0.693147
# ...

# %% [markdown]
# ## Feature importance:

# %%
pd.DataFrame(feature_importance.mean(axis = 'columns')).sort_values(0, ascending = False).head(10)
# Out:
#         0
# user  0.0

# %%
submission.head()
# Out:
#    user                 banque country  y  test  y_pred
# 0     1       Societe Generale  France  0  True     0.4
# 1     2        Credit Lyonnais  France  0  True     0.4
# 2     1  Chinese National Bank   China  1  True     0.4
# 3     2  Chinese National Bank   China  0  True     0.4
# 4     2                   QIWI  Russia  1  True     0.4

# %%
# If needed to rename the prediction variable:
submission.rename(columns= {'y_pred': 'prediction'})
# Out:
#    user                 banque country  y  test  prediction
# 0     1       Societe Generale  France  0  True         0.4
# 1     2        Credit Lyonnais  France  0  True         0.4
# 2     1  Chinese National Bank   China  1  True         0.4
# 3     2  Chinese National Bank   China  0  True         0.4
# 4     2                   QIWI  Russia  1  True         0.4

# %%
# submission[['y_pred']].to_csv(f'./submissions/submission_{scores_validation}.csv')

# %%
### Handle date.

### Exportation LightGBM en C.

### Exports columns to csv for embeddings computation.

### Calcul embeddings avec pipeline kaggle.

### Installation OSIRIM + google Drive

# %% [markdown]
# ### Treelite
#
# #### Download:
#
# ```
# !python3 -m pip install --user treelite treelite_runtime
# ```
#
# On Mac OSX:
#
# ```
# !brew install libomp
# ```
#
# #### Build from source:
#
# ```
# git clone https://github.com/dmlc/treelite.git
# cd treelite
#
# mkdir build
# cd build
# cmake ..
#
# Setup tools is needed to build from source
#
# pip install -U pip setuptools
#
# # Install treelite
# cd python
# python3 setup.py install --user
# # Install treelite_runtime
# cd ../runtime/python
# python3 setup.py install --user
#
# Set the environment variable PYTHONPATH to locate Treelite package
#
# export PYTHONPATH=/path/to/treelite/python:/path/to/treelite/runtime/python
# python3          # enter interactive session
# ```

# %%
def export_model_treelite(model, extension='so', toolchain='gcc'):
    # so for Unix and dylib for macos
    import treelite
    model.booster_.save_model('model.txt')
    treelite_model = treelite.Model.load('model.txt', model_format='lightgbm')
    treelite_model.export_lib(toolchain=toolchain, libpath=f'model.{extension}', params={'parallel_comp': 32}, verbose=True)
    
def load_model_treelite(extension='so'):
    # TARGET MACHINE
    import treelite_runtime
    return treelite_runtime.Predictor(f'model.{extension}', verbose=True)

def predict_treelite(predictor, X):
    # TARGET MACHINE
    import treelite_runtime
    batch = treelite_runtime.Batch.from_npy2d(X.values)
    return predictor.predict(batch, pred_margin=False)

#export_model_treelite(model=model, extension='so')
# predictor = load_model_treelite()
# predict_treelite(predictor, X_train)

# %% [markdown]
# ### Temporal validation:

# %% [raw]
# parameters = {
#     'num_leaves': 31,
#     'objective': 'binary',
#     'metric': ['binary_logloss'],
#     'num_leaves': 10,
#     'max_depth': - 1,
#     'learning_rate': 0.1,
#     'n_estimators': 100,
#     'random_state': 42,
#     'two_round': True
# }
#
#
#
#
# cv = model_selection.TimeSeriesSplit(2)
#
# model = lightgbm.LGBMClassifier(**parameters)
#
# submission = pd.DataFrame(index=X_test.index)
#
# for i, (fit, val) in enumerate(cv.split(X_train)): # groups
#
#     print(f'\n Fold {i+1} \n')
#
#     X_fit = X_train.loc[fit]
#     X_val = X_train.loc[val]
#
#     y_fit = y_train.loc[fit]
#     y_val = y_train.loc[val]
#
#     model.fit(X_fit, y_fit, eval_set = (X_val, y_val), early_stopping_rounds = 30)
#
#     y_val = pd.DataFrame(model.predict(X_val), index = X_val.index, columns = ['y_pred'])
#
#     # Overall score
#     score = scores_validation = custom_metric(
#         pd.concat([train.loc[val], y_val], axis = 'columns'),
#         metric=metrics.accuracy_score,
#         by='banque'
#     )
#
#     print(f'\n Fold {i+1} score: {score} \n')
#
#
# parameters['num_boost_round'] = model._best_iteration
#
# model.fit(X_fit, y_fit)
#
# # Submission
# submission['y_pred'] = model.predict(X_test)
# submission = pd.concat([test, submission['y_pred']], axis = 'columns')
