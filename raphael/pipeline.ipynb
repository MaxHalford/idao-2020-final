# %%
import pandas as pd
import numpy as np

# %%
from sklearn import preprocessing
from sklearn import model_selection

# %%
#pip install lightgbm
import lightgbm

# %%
train = pd.DataFrame({
    'user': [1, 2, 1, 2, 2],
    'banque': ['Societe Generale', 'Credit Lyonnais', 'Chinese National Bank', 'Chinese National Bank', 'QIWI'],
    'country': ['France', 'France', 'China', 'China', 'Russia'],
    'y': [0, 0, 1, 1, 1],
})

test  = pd.DataFrame({
    'user': [1, 2, 1, 2, 2],
    'banque': ['Societe Generale', 'Credit Lyonnais', 'Chinese National Bank', 'Chinese National Bank', 'QIWI'],
    'country': ['France', 'France', 'China', 'China', 'Russia'],
    'y': [0, 0, 1, 0, 1] ,
})

# %%
train = train.assign(test = False)
test  = test.assign(test = True)

# %%
df = pd.concat([train, test]).reset_index(drop = True)

# %% [markdown]
# ## Features computation:
#
# ['min', 'max', 'sum', 'mean', 'std']

# %% [markdown]
# ## Aggregate for Time series

# %%
def shifted_rolling_agg(df, AGGS, fillna=None):

    features = df.copy()

    for on, lag, by, hows in AGGS:

        agg = features.groupby(by)[on].apply(lambda x: (
            x
            .shift(1)
            .rolling(window=lag, min_periods=1)
            .agg(hows)
        ))

        agg = agg.rename(columns={
            how: f'{how}_of_last_{lag}_{on}_by_' + '_and_'.join(by)
            for how in hows
        })
        
        if fillna is not None:
            
            agg = agg.fillna(fillna)

        features = features.join(agg.astype(np.float32))
        
    return features

# AGGS = [
#   # on, lag, by, how
#   ('y', 2, ['banque'], ['mean']),
#    ('y', 2, ['user', 'banque'], ['mean']),
#    ('y', 2, ['user'], ['mean']),
# ]

# df = shifted_rolling_agg(df, AGGS, fillna = -1)

# %%
df.head()
# Out:
#    user                 banque country  y   test
# 0     1       Societe Generale  France  0  False
# 1     2        Credit Lyonnais  France  0  False
# 2     1  Chinese National Bank   China  1  False
# 3     2  Chinese National Bank   China  1  False
# 4     2                   QIWI  Russia  1  False

# %% [markdown]
# ## Aggregate:

# %%
def agg(df, AGGS, fillna=None):

    features = df.copy()

    for on, by, hows in AGGS:

        agg = features.groupby(by)[on].agg(hows).reset_index()
        
        names = {
            how: f'agg_{how}_{on}_by_' + '_and_'.join(by)
            for how in hows
        }

        agg = agg.rename(columns=names)
        
        for _, name in names.items():
        
            agg[name] = agg[name].astype(np.float32)
        
        if fillna is not None:
            
            agg = agg.fillna(fillna)
        
        features = pd.merge(left = features, right = agg, how = 'left', on = by)
        
    return features

#AGGS = [
#    # on, lag, by, how
#    ('y', ['banque'], ['mean']),
#    ('y', ['user', 'banque'], ['mean']),
#    ('y', ['user'], ['mean']),
#    ('y', ['country'], ['mean']),
#]

# df = agg(df, AGGS, fillna=-1)

# %%
df.head()
# Out:
#    user                 banque country  y   test
# 0     1       Societe Generale  France  0  False
# 1     2        Credit Lyonnais  France  0  False
# 2     1  Chinese National Bank   China  1  False
# 3     2  Chinese National Bank   China  1  False
# 4     2                   QIWI  Russia  1  False

# %% [markdown]
# ## Target encoding

# %%
def target_encoding(df, by, on, m):
    
    # Compute the global mean
    mean = df[on].mean()

    # Compute the number of values and the mean of each group
    agg = df.groupby(by)[on].agg(['count', 'mean'])
    counts = agg['count']
    means = agg['mean']

    # Compute the "smoothed" means
    smooth = (counts * means + m * mean) / (counts + m)

    # Replace each value by the according smoothed mean
    return df[by].map(smooth)

#AGGS = [
#    ('y', ['banque'], 0)
#]

#for on, by, m in AGGS:
    
#    name = f'target_encoding_on_{on}_by_{"_".join(by)}'
    
#    df[name] = target_encoding(df=df, by='banque', on='y', m=0.5)

# %%
df
# Out:
#    user                 banque country  y   test
# 0     1       Societe Generale  France  0  False
# 1     2        Credit Lyonnais  France  0  False
# 2     1  Chinese National Bank   China  1  False
# 3     2  Chinese National Bank   China  1  False
# 4     2                   QIWI  Russia  1  False
# 5     1       Societe Generale  France  0   True
# 6     2        Credit Lyonnais  France  0   True
# 7     1  Chinese National Bank   China  1   True
# 8     2  Chinese National Bank   China  0   True
# 9     2                   QIWI  Russia  1   True

# %% [markdown]
# ## Step since / Step until:

# %%
def steps_since(df, on, fillna=None, prefix=''):

    features = pd.DataFrame(index=df.index)

    for cat in df[on].astype('category').cat.categories:
        
        counts = df[on].eq(cat).cumsum()
        
        since = counts.groupby(counts).cumcount().astype('int64')
        
        since[counts.eq(0)] = pd.NA
        
        name = f'{prefix}{on}_steps_since_{cat}'
        
        features[name] = since
        
        if fillna is not None:
            
            features[name] = features[name].fillna(fillna)

    return features

# df = df.join(steps_since(df, on='banque', fillna=-1))

# %%
def grouped_steps_since(df, on, by, fillna=None):
    features = pd.concat(
        steps_since(df = group, on = on, fillna = fillna, prefix = f'agg_{"_".join(by)}_')
        for index, group in df.groupby(by)
    ).sort_index()
    
    if fillna is not None:
        
        features = features.fillna(fillna)
        
    return features

# df = df.join(grouped_steps_since(df=df, on='y', by=['banque'], fillna=-1))

# %% [markdown]
# ## Label encoding

# %%
categories = []#['banque', 'country']

# %%
label_encoder = {}

for category in categories:
    
    label_encoder[category] = preprocessing.LabelEncoder()
    
    df[category] = label_encoder[category].fit_transform(df[category])

# %% [markdown]
# ## Train test split:

# %%
numerical_columns = list(df.select_dtypes(include=np.number).columns)
numerical_columns
# Out:
# ['user', 'banque', 'country', 'y']

# %%
X_train = df[df['test'] == False][numerical_columns]
X_test  = df[df['test'] == False][numerical_columns]

# %% [markdown]
# #### Columns to drop:

# %%
columns_to_drop = []

# %%
X_train.drop(columns_to_drop, axis = 'columns', inplace = True)
X_test.drop(columns_to_drop, axis = 'columns', inplace = True)

# %% [markdown]
# #### Extract target

# %%
y_train = X_train['y']
X_train.drop('y', axis = 'columns', inplace = True)
X_test.drop('y', axis = 'columns', inplace = True)

# %%
X_train.head()
# Out:
#    user  banque  country
# 0     1       3        1
# 1     2       1        1
# 2     1       0        0
# 3     2       0        0
# 4     2       2        2

# %%
X_test.head()
# Out:
#    user  banque  country
# 0     1       3        1
# 1     2       1        1
# 2     1       0        0
# 3     2       0        0
# 4     2       2        2

# %% [markdown]
# #### Metric:

# %%
from sklearn import metrics

def custom_metric(oof, metric, by=None):
    if by is not None:
        grouped_scores = oof.groupby(by).apply(lambda group: metric(group.y, group.y_pred))
        print(grouped_scores)
        return grouped_scores.mean()
    else:
        return metric(oof.y, oof.y_pred)

# %% [markdown]
# #### CV with prediction:

# %%
parameters = {
    'num_leaves': 31, 
    'objective': 'binary', 
    'metric': ['auc'],
    'num_leaves': 31, 
    'max_depth': - 1, 
    'learning_rate': 0.1, 
    'n_estimators': 100,
    'random_state': 42,
    'two_round': True
}

cv = model_selection.KFold(5, shuffle = True)

# cv = model_selection.StratifiedKFold(5, shuffle = True)

model = lightgbm.LGBMClassifier(**parameters)

oof = []

submission = pd.DataFrame(index=X_test.index)

feature_importance = pd.DataFrame(index=X_train.columns)

for i, (fit, val) in enumerate(cv.split(X_train)): # groups
    
    print(f'\n Fold {i+1} \n')
    
    X_fit = X_train.loc[fit]
    X_val = X_train.loc[val]
    
    y_fit = y_train.loc[fit]
    y_val = y_train.loc[val]
    
    model.fit(X_fit, y_fit, eval_set = (X_val, y_val), early_stopping_rounds = 30)
    
    y_fit = pd.DataFrame(model.predict(X_fit), index = X_fit.index, columns = ['y_pred'])
    y_val = pd.DataFrame(model.predict(X_val), index = X_val.index, columns = ['y_pred'])
    
    submission[f'Fold {i}'] = model.predict(X_test)
    
    oof.append(
        pd.concat([train.loc[val], y_val], axis = 'columns')
    )
    
    feature_importance[f'Fold {i}'] = model.feature_importances_
    
    # Score for each fold on validation and train set:
    #scores_validation = custom_metric(
    #    pd.concat([train.loc[val], y_val], axis = 'columns'), 
    #    metric=metrics.accuracy_score, 
    #    by='banque',
    #)
    
    #scores_train = custom_metric(
    #    pd.concat([train.loc[fit], y_fit], axis = 'columns'), 
    #    metric=metrics.accuracy_score, 
    #    #by='banque'
    #)
    
    #print(f'Scores Train: {scores_train}, score valid: {scores_validation}')
    
# Concatenate out of fold prediction:
oof = pd.concat(oof).sort_index()

# Overall score
scores_validation = custom_metric(
    oof, 
    metric=metrics.accuracy_score, 
    #by='banque'
)

print(f'\n Validation score: {scores_validation} \n')


# Submission
submission['y_pred'] = submission.mean(axis='columns')
#submission['y_pred'] = submission.mode(axis='columns')

submission = pd.concat([test, submission['y_pred']], axis = 'columns')
# Out:
#  Fold 1
#
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 1
# [3]	valid_0's auc: 1
# [4]	valid_0's auc: 1
# [5]	valid_0's auc: 1
# [6]	valid_0's auc: 1
# [7]	valid_0's auc: 1
# [8]	valid_0's auc: 1
# [9]	valid_0's auc: 1
# [10]	valid_0's auc: 1
# [11]	valid_0's auc: 1
# [12]	valid_0's auc: 1
# [13]	valid_0's auc: 1
# [14]	valid_0's auc: 1
# [15]	valid_0's auc: 1
# [16]	valid_0's auc: 1
# [17]	valid_0's auc: 1
# [18]	valid_0's auc: 1
# [19]	valid_0's auc: 1
# [20]	valid_0's auc: 1
# [21]	valid_0's auc: 1
# [22]	valid_0's auc: 1
# [23]	valid_0's auc: 1
# [24]	valid_0's auc: 1
# [25]	valid_0's auc: 1
# [26]	valid_0's auc: 1
# [27]	valid_0's auc: 1
# [28]	valid_0's auc: 1
# [29]	valid_0's auc: 1
# [30]	valid_0's auc: 1
# [31]	valid_0's auc: 1
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
#  Fold 2
#
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 1
# [3]	valid_0's auc: 1
# [4]	valid_0's auc: 1
# [5]	valid_0's auc: 1
# [6]	valid_0's auc: 1
# [7]	valid_0's auc: 1
# [8]	valid_0's auc: 1
# [9]	valid_0's auc: 1
# [10]	valid_0's auc: 1
# [11]	valid_0's auc: 1
# [12]	valid_0's auc: 1
# [13]	valid_0's auc: 1
# [14]	valid_0's auc: 1
# [15]	valid_0's auc: 1
# [16]	valid_0's auc: 1
# [17]	valid_0's auc: 1
# [18]	valid_0's auc: 1
# [19]	valid_0's auc: 1
# [20]	valid_0's auc: 1
# [21]	valid_0's auc: 1
# [22]	valid_0's auc: 1
# [23]	valid_0's auc: 1
# [24]	valid_0's auc: 1
# [25]	valid_0's auc: 1
# [26]	valid_0's auc: 1
# [27]	valid_0's auc: 1
# [28]	valid_0's auc: 1
# [29]	valid_0's auc: 1
# [30]	valid_0's auc: 1
# [31]	valid_0's auc: 1
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
#  Fold 3
#
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 1
# [3]	valid_0's auc: 1
# [4]	valid_0's auc: 1
# [5]	valid_0's auc: 1
# [6]	valid_0's auc: 1
# [7]	valid_0's auc: 1
# [8]	valid_0's auc: 1
# [9]	valid_0's auc: 1
# [10]	valid_0's auc: 1
# [11]	valid_0's auc: 1
# [12]	valid_0's auc: 1
# [13]	valid_0's auc: 1
# [14]	valid_0's auc: 1
# [15]	valid_0's auc: 1
# [16]	valid_0's auc: 1
# [17]	valid_0's auc: 1
# [18]	valid_0's auc: 1
# [19]	valid_0's auc: 1
# [20]	valid_0's auc: 1
# [21]	valid_0's auc: 1
# [22]	valid_0's auc: 1
# [23]	valid_0's auc: 1
# [24]	valid_0's auc: 1
# [25]	valid_0's auc: 1
# [26]	valid_0's auc: 1
# [27]	valid_0's auc: 1
# [28]	valid_0's auc: 1
# [29]	valid_0's auc: 1
# [30]	valid_0's auc: 1
# [31]	valid_0's auc: 1
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
#  Fold 4
#
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 1
# [3]	valid_0's auc: 1
# [4]	valid_0's auc: 1
# [5]	valid_0's auc: 1
# [6]	valid_0's auc: 1
# [7]	valid_0's auc: 1
# [8]	valid_0's auc: 1
# [9]	valid_0's auc: 1
# [10]	valid_0's auc: 1
# [11]	valid_0's auc: 1
# [12]	valid_0's auc: 1
# [13]	valid_0's auc: 1
# [14]	valid_0's auc: 1
# [15]	valid_0's auc: 1
# [16]	valid_0's auc: 1
# [17]	valid_0's auc: 1
# [18]	valid_0's auc: 1
# [19]	valid_0's auc: 1
# [20]	valid_0's auc: 1
# [21]	valid_0's auc: 1
# [22]	valid_0's auc: 1
# [23]	valid_0's auc: 1
# [24]	valid_0's auc: 1
# [25]	valid_0's auc: 1
# [26]	valid_0's auc: 1
# [27]	valid_0's auc: 1
# [28]	valid_0's auc: 1
# [29]	valid_0's auc: 1
# [30]	valid_0's auc: 1
# [31]	valid_0's auc: 1
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
#  Fold 5
#
# [1]	valid_0's auc: 1
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 1
# [3]	valid_0's auc: 1
# [4]	valid_0's auc: 1
# [5]	valid_0's auc: 1
# [6]	valid_0's auc: 1
# [7]	valid_0's auc: 1
# [8]	valid_0's auc: 1
# [9]	valid_0's auc: 1
# [10]	valid_0's auc: 1
# [11]	valid_0's auc: 1
# [12]	valid_0's auc: 1
# [13]	valid_0's auc: 1
# [14]	valid_0's auc: 1
# [15]	valid_0's auc: 1
# [16]	valid_0's auc: 1
# [17]	valid_0's auc: 1
# [18]	valid_0's auc: 1
# [19]	valid_0's auc: 1
# [20]	valid_0's auc: 1
# [21]	valid_0's auc: 1
# [22]	valid_0's auc: 1
# [23]	valid_0's auc: 1
# [24]	valid_0's auc: 1
# [25]	valid_0's auc: 1
# [26]	valid_0's auc: 1
# [27]	valid_0's auc: 1
# [28]	valid_0's auc: 1
# [29]	valid_0's auc: 1
# [30]	valid_0's auc: 1
# [31]	valid_0's auc: 1
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1
#
#  Validation score: 0.0

# %% [markdown]
# ## Feature importance:

# %%
pd.DataFrame(feature_importance.mean(axis = 'columns')).sort_values(0, ascending = False).head(10)
# Out:
#            0
# user     0.0
# banque   0.0
# country  0.0

# %%
oof.head()
# Out:
#    user                 banque country  y   test  y_pred
# 0     1       Societe Generale  France  0  False       1
# 1     2        Credit Lyonnais  France  0  False       1
# 2     1  Chinese National Bank   China  1  False       1
# 3     2  Chinese National Bank   China  1  False       1
# 4     2                   QIWI  Russia  1  False       0

# %%
submission.head()
# Out:
#    user                 banque country  y  test  y_pred
# 0     1       Societe Generale  France  0  True     0.0
# 1     2        Credit Lyonnais  France  0  True     0.0
# 2     1  Chinese National Bank   China  1  True     0.0
# 3     2  Chinese National Bank   China  0  True     0.0
# 4     2                   QIWI  Russia  1  True     0.0

# %%
# If needed to rename the prediction variable:
submission.rename(columns= {'y_pred': 'prediction'})
# Out:
#    user                 banque country  y  test  prediction
# 0     1       Societe Generale  France  0  True         0.0
# 1     2        Credit Lyonnais  France  0  True         0.0
# 2     1  Chinese National Bank   China  1  True         0.0
# 3     2  Chinese National Bank   China  0  True         0.0
# 4     2                   QIWI  Russia  1  True         0.0

# %%
# submission[['y_pred']].to_csv(f'./submission/submission_{scores_validation}.csv')

# %%
### Handle date.

### Exportation LightGBM en C.

### Exports columns to csv for embeddings computation.

### Calcul embeddings avec pipeline kaggle.

### Installation OSIRIM + google Drive

# %% [markdown]
# ### Temporal validation:

# %%
parameters = {
    'num_leaves': 31, 
    'objective': 'binary', 
    'metric': ['auc', 'binary_logloss'],
    'num_leaves': 31, 
    'max_depth': - 1, 
    'learning_rate': 0.1, 
    'n_estimators': 100,
    'random_state': 42,
    'two_round': True
}


cv = model_selection.TimeSeriesSplit(2) 

model = lightgbm.LGBMClassifier(**parameters)

submission = pd.DataFrame(index=X_test.index)

for i, (fit, val) in enumerate(cv.split(X_train)): # groups
    
    print(f'\n Fold {i+1} \n')
    
    X_fit = X_train.loc[fit]
    X_val = X_train.loc[val]
    
    y_fit = y_train.loc[fit]
    y_val = y_train.loc[val]
    
    model.fit(X_fit, y_fit, eval_set = (X_val, y_val), early_stopping_rounds = 30)
    
    y_val = pd.DataFrame(model.predict(X_val), index = X_val.index, columns = ['y_pred'])
    
    # Overall score
    score = scores_validation = custom_metric(
        pd.concat([train.loc[val], y_val], axis = 'columns'), 
        metric=metrics.accuracy_score, 
        by='banque'
    )
    
    print(f'\n Fold {i+1} score: {score} \n')
    
    
parameters['num_boost_round'] = model._best_iteration

model.fit(X_fit, y_fit)

# Submission
submission['y_pred'] = model.predict(X_test)
submission = pd.concat([test, submission['y_pred']], axis = 'columns')
# Out:
#  Fold 1
#
# [1]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [3]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [4]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [5]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [6]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [7]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [8]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [9]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [10]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [11]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [12]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [13]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [14]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [15]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [16]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [17]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [18]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [19]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [20]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [21]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [22]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [23]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [24]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [25]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [26]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [27]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [28]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [29]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [30]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# [31]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1	valid_0's binary_logloss: 1.60944
# banque
# Chinese National Bank    0.0
# dtype: float64
#
#  Fold 1 score: 0.0
#
#
#  Fold 2
#
# [1]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# Training until validation scores don't improve for 30 rounds
# [2]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [3]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [4]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [5]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [6]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [7]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [8]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [9]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [10]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [11]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [12]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [13]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [14]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [15]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [16]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [17]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [18]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [19]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [20]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [21]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [22]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [23]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [24]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [25]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [26]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [27]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [28]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [29]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [30]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# [31]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# Early stopping, best iteration is:
# [1]	valid_0's auc: 1	valid_0's binary_logloss: 0.693147
# banque
# QIWI    0.0
# dtype: float64
#
#  Fold 2 score: 0.0
